# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data = pd.read_excel('/agri.xlsx')

# %%
data.head()
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      780                      870
# 1                      800                      880
# 2                      830                      930
# 3                      820                      920
# 4                      860                      940
#
#    Modal Price (Rs./Quintal) Price Date
# 0                        825 2022-03-30
# 1                        840 2022-03-29
# 2                        880 2022-03-28
# 3                        870 2022-03-27
# 4                        900 2022-03-26

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14806 entries, 0 to 14805
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl no.                     14806 non-null  int64
#  1   District Name              14806 non-null  object
#  2   Market Name                14806 non-null  object
#  3   Commodity                  14806 non-null  object
#  4   Variety                    14806 non-null  object
#  5   Grade                      14806 non-null  object
#  6   Min Price (Rs./Quintal)    14806 non-null  int64
#  7   Max Price (Rs./Quintal)    14806 non-null  int64
#  8   Modal Price (Rs./Quintal)  14806 non-null  int64
#  9   Price Date                 14806 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#              Sl no.  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# count  14806.000000             14806.000000             14806.000000
# mean    7403.500000               679.884979               769.840673
# std     4274.268378               498.112289               532.838595
# min        1.000000                 0.000000                 0.000000
# 25%     3702.250000               350.000000               440.000000
# 50%     7403.500000               600.000000               700.000000
# 75%    11104.750000               910.000000              1050.000000
# max    14806.000000              3750.000000              4750.000000
#
#        Modal Price (Rs./Quintal)
# count               14806.000000
# mean                  838.016277
# std                   453.052665
# min                     0.000000
# 25%                   490.000000
# 50%                   780.000000
# 75%                  1050.000000
# max                 10100.000000

# %%
data.isnull().sum()
# Out:
# Sl no.                       0
# District Name                0
# Market Name                  0
# Commodity                    0
# Variety                      0
# Grade                        0
# Min Price (Rs./Quintal)      0
# Max Price (Rs./Quintal)      0
# Modal Price (Rs./Quintal)    0
# Price Date                   0
# dtype: int64

# %%
data = data.dropna()

# %%
data.head()
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1          Agra     Achnera    Potato    Desi   FAQ
# 1       2          Agra     Achnera    Potato    Desi   FAQ
# 2       3          Agra     Achnera    Potato    Desi   FAQ
# 3       4          Agra     Achnera    Potato    Desi   FAQ
# 4       5          Agra     Achnera    Potato    Desi   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                      780                      870
# 1                      800                      880
# 2                      830                      930
# 3                      820                      920
# 4                      860                      940
#
#    Modal Price (Rs./Quintal) Price Date
# 0                        825 2022-03-30
# 1                        840 2022-03-29
# 2                        880 2022-03-28
# 3                        870 2022-03-27
# 4                        900 2022-03-26

# %% [markdown]
# # a

# %%
data = data.sort_values(by = "Price Date")

# %%
data
# Out:
#        Sl no. District Name     Market Name Commodity Variety Grade  \
# 1933     1934          Agra         Achnera    Potato   Other   FAQ
# 10009   10010          Agra         Jagnair    Potato   Other   FAQ
# 13806   13807          Agra      Khairagarh    Potato   Other   FAQ
# 8348     8349          Agra  Fatehpur Sikri    Potato   Other   FAQ
# 1932     1933          Agra         Achnera    Potato   Other   FAQ
# ...       ...           ...             ...       ...     ...   ...
# 6565     6566          Agra  Fatehpur Sikri    Potato   Local   FAQ
# 10882   10883          Agra      Khairagarh    Potato    Desi   FAQ
# 8349     8350          Agra         Jagnair    Potato    Desi   FAQ
# 1934     1935          Agra            Agra    Potato    Desi   FAQ
# 6564     6565          Agra  Fatehpur Sikri    Potato   Local   FAQ
#
#        Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 1933                       320                      400
# ...

# %% [markdown]
# # b

# %%
data.columns
# Out:
# Index(['Sl no.', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal Price (Rs./Quintal)', 'Price Date'],
#       dtype='object')

# %%
for col in ['District Name', 'Market Name', 'Commodity', 'Variety','Grade' ]:
  print(data[col].unique())
# Out:
# ['Agra']
# ['Achnera' 'Jagnair' 'Khairagarh' 'Fatehpur Sikri' 'Agra' 'Fatehabad'
#  'Samsabad' 'Jarar']
# ['Potato']
# ['Other' 'Desi' 'Potato' 'F.A.Q.' 'Local' 'Chips']
# ['FAQ']

# %%
for col in [ 'Market Name', 'Variety']:
  print(data[col].value_counts())
# Out:
# Agra              3124
# Khairagarh        2925
# Achnera           1934
# Fatehpur Sikri    1785
# Jagnair           1661
# Fatehabad         1506
# Samsabad           999
# Jarar              872
# Name: Market Name, dtype: int64
# Desi      8884
# Local     2761
# Other     2717
# Potato     396
# Chips       37
# F.A.Q.      11
# Name: Variety, dtype: int64

# %%
sns.displot(data['Modal Price (Rs./Quintal)'], kde=True, bins=30)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Market Name',y='Modal Price (Rs./Quintal)', data=data)

# %%
data[data['Modal Price (Rs./Quintal)'] == data['Modal Price (Rs./Quintal)'].max()]
# Out:
#       Sl no. District Name Market Name Commodity Variety Grade  \
# 3494    3495          Agra        Agra    Potato   Local   FAQ
#
#       Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 3494                        0                        0
#
#       Modal Price (Rs./Quintal) Price Date
# 3494                      10100 2016-10-20

# %%
data = data.drop([3494], axis=0)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Market Name',y='Modal Price (Rs./Quintal)', data=data)

# %%
sns.boxplot(x='Variety',y='Modal Price (Rs./Quintal)', data=data)

# %%
data['year'] = data['Price Date'].apply(lambda x:str(x.year))
data['month'] = data['Price Date'].apply(lambda x:str(x.month))

# %%
data
# Out:
#        Sl no. District Name     Market Name Commodity Variety Grade  \
# 1933     1934          Agra         Achnera    Potato   Other   FAQ
# 10009   10010          Agra         Jagnair    Potato   Other   FAQ
# 13806   13807          Agra      Khairagarh    Potato   Other   FAQ
# 8348     8349          Agra  Fatehpur Sikri    Potato   Other   FAQ
# 1932     1933          Agra         Achnera    Potato   Other   FAQ
# ...       ...           ...             ...       ...     ...   ...
# 6565     6566          Agra  Fatehpur Sikri    Potato   Local   FAQ
# 10882   10883          Agra      Khairagarh    Potato    Desi   FAQ
# 8349     8350          Agra         Jagnair    Potato    Desi   FAQ
# 1934     1935          Agra            Agra    Potato    Desi   FAQ
# 6564     6565          Agra  Fatehpur Sikri    Potato   Local   FAQ
#
#        Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 1933                       320                      400
# ...

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data
# Out:
#        Sl no.  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 1933     1934                      320                      400
# 10009   10010                      330                      400
# 13806   13807                      500                      600
# 8348     8349                      290                      315
# 1932     1933                      300                      400
# ...       ...                      ...                      ...
# 6565     6566                      700                      950
# 10882   10883                      750                      850
# 8349     8350                      850                      950
# 1934     1935                      750                      950
# 6564     6565                      700                     1000
#
#        Modal Price (Rs./Quintal) Price Date  District Name_Agra  \
# 1933                         370 2011-01-01                   1
# 10009                        350 2011-01-01                   1
# ...

# %%
data.columns
# Out:
# Index(['Sl no.', 'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal Price (Rs./Quintal)', 'Price Date', 'District Name_Agra',
#        'Market Name_Achnera', 'Market Name_Agra', 'Market Name_Fatehabad',
#        'Market Name_Fatehpur Sikri', 'Market Name_Jagnair',
#        'Market Name_Jarar', 'Market Name_Khairagarh', 'Market Name_Samsabad',
#        'Commodity_Potato', 'Variety_Chips', 'Variety_Desi', 'Variety_F.A.Q.',
#        'Variety_Local', 'Variety_Other', 'Variety_Potato', 'Grade_FAQ',
#        'year_2011', 'year_2012', 'year_2013', 'year_2014', 'year_2015',
#        'year_2016', 'year_2017', 'year_2018', 'year_2019', 'year_2020',
#        'year_2021', 'year_2022', 'month_1', 'month_10', 'month_11', 'month_12',
#        'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
#        'month_8', 'month_9'],
#       dtype='object')

# %%
df = data[['Modal Price (Rs./Quintal)','Market Name_Achnera', 'Market Name_Agra', 'Market Name_Fatehabad',
       'Market Name_Fatehpur Sikri', 'Market Name_Jagnair',
       'Market Name_Jarar', 'Market Name_Khairagarh', 'Market Name_Samsabad',
       'Variety_Chips', 'Variety_Desi', 'Variety_F.A.Q.',
       'Variety_Local', 'Variety_Other', 'Variety_Potato',
       'year_2011', 'year_2012', 'year_2013', 'year_2014', 'year_2015',
       'year_2016', 'year_2017', 'year_2018', 'year_2019', 'year_2020',
       'year_2021', 'year_2022', 'month_1', 'month_10', 'month_11', 'month_12',
       'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
       'month_8', 'month_9']]

# %%
df.head()
# Out:
#        Modal Price (Rs./Quintal)  Market Name_Achnera  Market Name_Agra  \
# 1933                         370                    1                 0
# 10009                        350                    0                 0
# 13806                        550                    0                 0
# 8348                         300                    0                 0
# 1932                         360                    1                 0
#
#        Market Name_Fatehabad  Market Name_Fatehpur Sikri  Market Name_Jagnair  \
# 1933                       0                           0                    0
# 10009                      0                           0                    1
# 13806                      0                           0                    0
# 8348                       0                           1                    0
# 1932                       0                           0                    0
#
# ...

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop("Modal Price (Rs./Quintal)", axis=1)

# %%
y = df['Modal Price (Rs./Quintal)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=101)

# %% [markdown]
# # XGBoost Regressor

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBRegressor()

# %%
xg_reg.fit(x_train, y_train)
# Out:
# [17:37:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
predictions = xg_reg.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mae = mean_absolute_error(y_test, predictions)

# %%
mae
# Out:
# 122.00035834972476

# %%
r2_score(y_test, predictions)
# Out:
# 0.8428068342022969

# %%
sns.displot(y_test-predictions, bins=30, kde=True)

# %%
sns.scatterplot(x=y_test,y=y_test-predictions)
plt.axhline(y=0, color='r', linestyle='--')
